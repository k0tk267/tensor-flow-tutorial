# %%
import tensorflow as tf

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE

# %%
import pathlib
data_root_orig = tf.keras.utils.get_file(origin='https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz',
                                         fname='flower_photos', untar=True)
data_root = pathlib.Path(data_root_orig)
print(data_root)
# Out:
# ...
# 228818944/228813984 [==============================] - 20s 0us/step
# C:\Users\intern1\.keras\datasets\flower_photos

# %%
for item in data_root.iterdir():
    print(item)
# Out:
# C:\Users\intern1\.keras\datasets\flower_photos\daisy
# C:\Users\intern1\.keras\datasets\flower_photos\dandelion
# C:\Users\intern1\.keras\datasets\flower_photos\LICENSE.txt
# C:\Users\intern1\.keras\datasets\flower_photos\roses
# C:\Users\intern1\.keras\datasets\flower_photos\sunflowers
# C:\Users\intern1\.keras\datasets\flower_photos\tulips

# %%
all_image_paths = list(data_root.glob('*/*'))
all_image_paths
# Out:
# [WindowsPath('C:/Users/intern1/.keras/datasets/flower_photos/daisy/100080576_f52e8ee070_n.jpg'),
#  WindowsPath('C:/Users/intern1/.keras/datasets/flower_photos/daisy/10140303196_b88d3d6cec.jpg'),
#  WindowsPath('C:/Users/intern1/.keras/datasets/flower_photos/daisy/10172379554_b296050f82_n.jpg'),
#  WindowsPath('C:/Users/intern1/.keras/datasets/flower_photos/daisy/10172567486_2748826a8b.jpg'),
#  WindowsPath('C:/Users/intern1/.keras/datasets/flower_photos/daisy/10172636503_21bededa75_n.jpg'),
#  WindowsPath('C:/Users/intern1/.keras/datasets/flower_photos/daisy/102841525_bd6628ae3c.jpg'),
#  WindowsPath('C:/Users/intern1/.keras/datasets/flower_photos/daisy/1031799732_e7f4008c03.jpg'),
#  WindowsPath('C:/Users/intern1/.keras/datasets/flower_photos/daisy/10391248763_1d16681106_n.jpg'),
#  WindowsPath('C:/Users/intern1/.keras/datasets/flower_photos/daisy/10437754174_22ec990b77_m.jpg'),
#  WindowsPath('C:/Users/intern1/.keras/datasets/flower_photos/daisy/10437770546_8bb6f7bdd3_m.jpg'),
# ...

# %%
import random
all_image_paths = list(data_root.glob('*/*')) #これなに？？
all_image_paths = [str(path) for path in all_image_paths]
random.shuffle(all_image_paths)

image_count = len(all_image_paths)
image_count
# Out:
# 3670

# %%
all_image_paths[:10]
# Out:
# ['C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\daisy\\4131565290_0585c4dd5a_n.jpg',
#  'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\sunflowers\\9558627290_353a14ba0b_m.jpg',
#  'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\sunflowers\\9681915384_b3b646dc92_m.jpg',
#  'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\sunflowers\\5004121118_e9393e60d0_n.jpg',
#  'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\roses\\6111589202_8b9555364c_m.jpg',
#  'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\roses\\8524505682_bda885af3a_n.jpg',
#  'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\dandelion\\2634666217_d5ef87c9f7_m.jpg',
#  'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\sunflowers\\5020805135_1219d7523d.jpg',
#  'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\dandelion\\17388674711_6dca8a2e8b_n.jpg',
#  'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\dandelion\\7099259755_1c66420206_n.jpg']

# %%
import os
attributions = (data_root/"LICENSE.txt").open(encoding='utf-8').readlines()[4:]
attributions = [line.split(' CC-BY') for line in attributions]
attributions = dict(attributions)

# %%
import IPython.display as display

def caption_image(image_path):
    image_rel = pathlib.Path(image_path).relative_to(data_root)
    image_rel_str = str(pathlib.Path(image_path).relative_to(data_root)).replace('\\', '/')
    return "Image (CC BY 2.0) " + ' - '.join(attributions[str(image_rel_str)].split(' - ')[:-1])

# %%
for n in range(3):
    image_path = random.choice(all_image_paths)
    display.display(display.Image(image_path))
    print(caption_image(image_path))
    print()
# Out:
# Image (CC BY 2.0)  by Mike Mozart
# Image (CC BY 2.0)  by Robert Couse-Baker
# Image (CC BY 2.0)  by the_steve_cox

# %%
image_rel = pathlib.Path(image_path).relative_to(data_root)
image_rel_str = str(pathlib.Path(image_path).relative_to(data_root)).replace('\\', '/')

print(image_rel)
print(image_rel_str)
# Out:
# dandelion\3518608454_c3fd3c311c_m.jpg
# dandelion/3518608454_c3fd3c311c_m.jpg

# %%
print(attributions)
# Out:
# {'daisy/7568630428_8cf0fc16ff_n.jpg': ' by A Guy Taking Pictures - https://www.flickr.com/photos/80901381@N04/7568630428/\n', 'daisy/7410356270_9dff4d0e2e_n.jpg': ' by martinak15 - https://www.flickr.com/photos/martinaphotography/7410356270/\n', 'daisy/4286053334_a75541f20b_m.jpg': ' by jenny downing - https://www.flickr.com/photos/jenny-pics/4286053334/\n', 'daisy/10770585085_4742b9dac3_n.jpg': ' by Thangaraj Kumaravel - https://www.flickr.com/photos/kumaravel/10770585085/\n', 'daisy/8759177308_951790e00d_m.jpg': ' by Marina del Castell - https://www.flickr.com/photos/marinadelcastell/8759177308/\n', 'daisy/4131565290_0585c4dd5a_n.jpg': ' by jenny downing - https://www.flickr.com/photos/jenny-pics/4131565290/\n', 'daisy/3504430338_77d6a7fab4_n.jpg': ' by Dhilung Kirat - https://www.flickr.com/photos/dhilung/3504430338/\n', 'daisy/3084924076_4d5c5711af_m.jpg': ' by Bùi Linh Ngân - https://www.flickr.com/photos/linhngan/3084924076/\n', 'daisy/2642408410_61545fdc83_n.jpg': ' by Dennis 
# ...

# %%
print(all_image_paths)
# Out:
# ['C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\daisy\\4131565290_0585c4dd5a_n.jpg', 'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\sunflowers\\9558627290_353a14ba0b_m.jpg', 'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\sunflowers\\9681915384_b3b646dc92_m.jpg', 'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\sunflowers\\5004121118_e9393e60d0_n.jpg', 'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\roses\\6111589202_8b9555364c_m.jpg', 'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\roses\\8524505682_bda885af3a_n.jpg', 'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\dandelion\\2634666217_d5ef87c9f7_m.jpg', 'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\sunflowers\\5020805135_1219d7523d.jpg', 'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\dandelion\\17388674711_6dca8a2e8b_n.jpg', 'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\dandelion\\7099259755_1c66420206_n.jpg', 'C:\\Users\\intern1\\.keras\\datasets\\flower_photos\\su
# ...
